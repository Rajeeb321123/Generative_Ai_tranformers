# %% [markdown]
# # Load the Dataset

# %%
from datasets import load_dataset
dataset_1 = load_dataset("yahma/alpaca-cleaned", split = "train", cache_dir='cache_dir_dataset').to_pandas()
dataset_1.head()

# %%
import pandas as pd

# %%
# droping any row with null value
df = dataset_1.dropna(axis=0)
df = a = df.reset_index(drop =True) # index is all messed up after drop so we resetindex.
print("The number of Dropped rows:",dataset_1.shape[0]-df.shape[0])
null_count_dataset_1 = dataset_1.isnull().sum().sum()
null_count_df = df.isnull().sum().sum()
print("total number of null values in dataset_1 and df:",null_count_dataset_1, "and", null_count_df)

# %%
# counting total character in dataset
total_character = 0
for index_1, row in df.iterrows():
    total_character = len(row["instruction"]) + len(row["input"]) + len(row["output"]) + total_character
print(total_character)

# %%
# counting the number of value we won't going to translate
no_translate = 0
for index_1, row in df.iterrows():
    if (len(row["instruction"]) == 0):
        no_translate += 1
    if (len(row["input"]) == 0):
        no_translate += 1
    if (len(row["output"]) == 0):
        no_translate += 1
print(no_translate)

# %%
# len of dataset
len(df), len(dataset_1)

# %%
# rename the name of column
df.head()

# %%
# rechecking the null value
null_count_df = df.isnull().sum().sum()
null_count_df

# %%
# Checking the max_length in whole dataset
max_length = 0
for index, row in df.iterrows():
    if (len(row["instruction"])> max_length):
        max_length = len(row["instruction"])
    if (len(row["input"])> max_length):
        max_length = len(row["input"])
    if (len(row["output"])> max_length):
        max_length = len(row["output"])
    
    
print(max_length)

# %% [markdown]
# # for Initial (save the out.csv)

# %%
df_2 = pd.DataFrame(columns=['instruction', 'input', 'output'])

# %%
df_2.head()

# %%
import ollama
def ollama_llm(question):
    if (len(question) > 0):
        formatted_prompt = question
        response = ollama.generate(
            #model = "qwen_7b_16bit_2-q5_k_m:latest", # for more creative answer: temperature 0.7
            model='llama_6k_0.1:latest ', # more precise answer: temperature 0.1
            prompt=formatted_prompt
        )
        return response['response']
    else:
        return ""

# %%
ollama_llm("""The fraction 4/16 is equivalent to 1/4 because both fractions represent the same value. A fraction can be simplified by dividing both the numerator and the denominator by a common factor. In this case, 4 is a common factor of both the numerator and the denominator of 4/16. When we divide both by 4, we get 4/4 = 1 and 16/4 = 4, so the simplified fraction is 1/4. Alternatively, we can think of this in terms of multiplication. For example, if we multiply the numerator and denominator of the fraction 1/4 by 4, we get (1x4)/(4x4), or 4/16. Since both fractions can be derived from the other through multiplication or division by the same number, they represent the same value and are equivalent.""")

# %%
# %%time
for index, row in df[:1000].iterrows():
    
    nepali_instruction = ollama_llm(row["instruction"])
    nepali_input = ollama_llm(row["input"])
    nepali_output = ollama_llm(row["output"])
    
    new_dic = {"instruction": [nepali_instruction], "input": [nepali_input], "output": [nepali_output] }
    temp_df = pd.DataFrame(new_dic)
    # display(temp_df)

    df_2 = pd.concat([df_2, temp_df], ignore_index = True)
    df_2.reset_index()
    df_2.to_csv('out.csv')
    print(index)

# %%
df_2.iloc[1]["output"]

# %% [markdown]
# # From load from csv

# %%
import pandas as pd

df_2 = pd.read_csv('out.csv')
df_2 = df_2.drop(columns = ['Unnamed: 0'])
df_2 = df_2.fillna('')
df_2.head()
# Out:
#                                          instruction input  \
# 0                           तीन स्वस्थ रहने तरिकाहरू
# 1                        तीन प्राथमिक रङहरू के हुन्?
# 2                एक परमाणुको संरचना वर्णन गर्नुहोस्।
# 3                कसरी हावाको प्रदूषण कम गर्न सकिन्छ?
# 4  मैले निर्माण कम्पनीको परियोजना प्रबन्धकको रूपम...
#
#                                               output
# 0  1. स्वस्थ र सन्तुलित आहार खानुहोस्: आफ्नो भोजन...
# 1  तीन प्राथमिक रङहरू रातो, नीलो र सुनौला हुन्। य...
# 2  एक परमाणु सबै पदार्थको आधारभूत निर्माण इकाई हो...
# 3     वायु प्रदूषण कम गर्नका लागि धेरै तरिकाहरू छन्:
# 4  मैले निर्माण कम्पनीमा परियोजना प्रबन्धकको रूपम...

# %%
df_2.tail()
# Out:
#                                            instruction  \
# 171  कुनै विशेष जनावरलाई वर्णन गर्ने पाँच वाक्यका श...
# 172  The United States has been a global leader in ...
# 173  Once upon a time, there was a young girl named...
# 174  The given sentence is already in active voice:...
# 175  किनभने यो विषय महत्त्वपूर्ण छ भनेर कारण बताउनु...
#
#                                                  input  \
# 171                                               सिंह
# 172                             पानीमुनिका जीवहरू रोचक
# 173  उनले ढोका खोलेर एक अग्लो व्यक्ति अँध्यारोमा लु...
# 174                     एक सय पचासवटा किताब बिक्री भए।
# 175                                    वातावरण संरक्षण
#
#                                                 output
# 171                 सुन्दर, शक्तिशाली, घमण्डी र शासकीय
# 172                        पानीमुनिका जीवहरू रोचक छन्।
# 173  उनले ढोका खोलेर एक अग्लो व्यक्ति अँध्यारोमा लु...
# 174                  कसैले एक सय पचासवटा किताब बेच्यो।
# ...

# %%
# rechecking the null value
null_count_df_2 = df_2.isnull().sum().sum()
null_count_df_2
# Out:
# 0

# %%
len(df_2)
# Out:
# 176

# %%
import ollama
def ollama_llm(question):
    if (len(question) > 0):
        formatted_prompt = question
        response = ollama.generate(
            #model = "qwen_7b_16bit_2-q5_k_m:latest", # for more creative answer: temperature 0.7
            model='llama_6k_0.1:latest ', # more precise answer: temperature 0.1
            prompt=formatted_prompt
        )
        return response['response']
    else:
        return ""

# %%
# df.at[index, "instruction"] = row["instruction"]

# %%
# %%time
for index, row in df[176:2000].iterrows():
    
    nepali_instruction = ollama_llm(row["instruction"])
    nepali_input = ollama_llm(row["input"])
    nepali_output = ollama_llm(row["output"])
    
    new_dic = {"instruction": [nepali_instruction], "input": [nepali_input], "output": [nepali_output] }
    temp_df = pd.DataFrame(new_dic)
    # display(temp_df)

    df_2 = pd.concat([df_2, temp_df], ignore_index = True)
    df_2.reset_index()
    df_2.to_csv('out.csv')
    print(index)
# Out:
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# ...
